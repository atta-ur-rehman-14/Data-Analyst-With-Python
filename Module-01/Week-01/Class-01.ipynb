# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
key = "Hello"
print(key)
# Out:
# Hello

# %%
print(10)
# Out:
# 10

# %%
print(10
# Out:
#   Cell In[4], line 1
#     print(10
#             ^
# _IncompleteInputError: incomplete input

# %%
print(Hello world)
# Out:
#   Cell In[5], line 1
#     print(Hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# # Variables
# - Contaoners that store a Data

# %%
City = "Lahore"   # Variable Name -- Lahore is Varaible Value
Age= 22

# %%
print(City)
print(Age)
# Out:
# Lahore
# 22

# %%
Age = 25

# %%
print(Age)
# Out:
# 25

# %%
Age = 33

# %%
print(Age)
# Out:
# 33

# %%
Age_Student1 = 44
Age_Student2 = 66

# %%
print(Age_Student1)
print(Age_Student2)
# Out:
# 44
# 66

# %%
x= 500
y = 0.17
z= x * y
print(z)
# Out:
# 85.0

# %%
Bill = 500
Tax_rate = 0.15
Tax_amount = Bill * Tax_rate
print(Tax_amount)

Total_Bill = Bill + Tax_amount
print(Total_Bill)
# Out:
# 75.0
# 575.0

# %% [markdown]
# # Data Types

# %%
# 1. Int --> 12,34,55
# 2. Float --> 1.3,0.5,2.4
# 3. String --> "Heloo"
# 4. Boolean --> True/False

# %%
Is_Sunday = False
print(Is_Sunday)
# Out:
# False

# %% [markdown]
# # Type

# %%
print(type(Is_Sunday))
# Out:
# <class 'bool'>

# %%
num = 12.4
print(type(num))
# Out:
# <class 'float'>

# %%
name = "Atta Ur Rehman"
print(type(name))
# Out:
# <class 'str'>

# %%
first = "Data"
Second = "Engineer"

role = first + " " + Second
print(role)

# print(first,Second)
# print("Data Engineer")
# print("Data" , "Engineer")
# Out:
# Data Engineer

# %%
print(11+345)  # ab + cde --> abcde
# Out:
# 356

# %%
# > < 

files_processed = 47
target = 50
target_met = files_processed > target

print(target_met)
print(type(target_met))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# # Type Conversion

# %%
Ans = 16.6
# Int
Ans= int(Ans)
print(Ans)
print(type(Ans))
# Out:
# 16
# <class 'int'>

# %%
age = 10 

# float
age = float(age)
print(age)
print(type(age))
# Out:
# 10.0
# <class 'float'>

# %%
number = "100"
print(type(number))
number = int(number)
print(type(number))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name = "Atta Ur Rehman"
print(type(name))

name = int(name)
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 4
#       1 name = "Atta Ur Rehman"
#       2 print(type(name))
#       3
# ----> 4 name = int(name)
#
# ValueError: invalid literal for int() with base 10: 'Atta Ur Rehman'
